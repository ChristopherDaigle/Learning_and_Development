# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_html('https://money.cnn.com/news/specials/storysupplement/census_income/')[1]
print(df.columns)
df.head()
# Out:
# Index(['State', 'Median income', '% of people living in poverty',
#        '% of people without health insurance'],
#       dtype='object')
#         State Median income % of people living in poverty  \
# 0     Alabama       $40,554                         16.9%
# 1      Alaska       $64,333                          8.9%
# 2     Arizona       $49,889                         14.2%
# 3    Arkansas       $38,134                         17.9%
# 4  California       $59,948                         12.4%
#
#   % of people without health insurance
# 0                                12.0%
# 1                                18.2%
# 2                                18.3%
# 3                                16.1%
# 4                                18.2%

# %%
df.sort_values(by = 'col2', axis = 0)
# Out:
#         State Median income % of people living in poverty  \
# 0     Alabama       $40,554                         16.9%
# 1      Alaska       $64,333                          8.9%
# 2     Arizona       $49,889                         14.2%
# 3    Arkansas       $38,134                         17.9%
# 4  California       $59,948                         12.4%
#
#   % of people without health insurance
# 0                                12.0%
# 1                                18.2%
# 2                                18.3%
# 3                                16.1%
# 4                                18.2%

# %%
df.sort_values(by = '% of people living in poverty', axis = 0).tail(10)
# Out:
#             State Median income % of people living in poverty  \
# 6     Connecticut       $65,967                          7.9%
# 11         Hawaii       $63,746                          8.0%
# 20       Maryland       $68,080                          8.3%
# 30     New Jersey       $67,035                          8.6%
# 51        Wyoming       $51,731                          8.7%
# 1          Alaska       $64,333                          8.9%
# 23      Minnesota       $55,802                          9.5%
# 45           Utah       $55,109                          9.7%
# 47       Virginia       $59,562                          9.9%
# 21  Massachusetts       $62,365                          9.9%
#
#    % of people without health insurance
# 6                                  9.4%
# 11                                 7.5%
# 20                                13.7%
# 30                                15.8%
# 51                                13.6%
# ...
