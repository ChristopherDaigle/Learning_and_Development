# %% [markdown]
# # Week 3

# %% [markdown]
# ### Using Python with data: CSV

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('gapminder_all.csv')

# %%
df.head()
# Out:
#   continent       country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 0    Africa       Algeria     2449.008185     3013.976023     2550.816880
# 1    Africa        Angola     3520.610273     3827.940465     4269.276742
# 2    Africa         Benin     1062.752200      959.601080      949.499064
# 3    Africa      Botswana      851.241141      918.232535      983.653976
# 4    Africa  Burkina Faso      543.255241      617.183465      722.512021
#
#    gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# 0     3246.991771     4182.663766     4910.416756     5745.160213
# 1     5522.776375     5473.288005     3008.647355     2756.953672
# 2     1035.831411     1085.796879     1029.161251     1277.897616
# 3     1214.709294     2263.611114     3214.857818     4551.142150
# 4      794.826560      854.735976      743.387037      807.198586
#
#    gdpPercap_1987    ...       pop_1962    pop_1967    pop_1972    pop_1977  \
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=142, step=1)

# %%
df1 = df.set_index('country')
df2 = pd.read_csv('gapminder_all.csv', index_col= 'country')

# %%
df1.head()
# Out:
#              continent  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Algeria         Africa     2449.008185     3013.976023     2550.816880
# Angola          Africa     3520.610273     3827.940465     4269.276742
# Benin           Africa     1062.752200      959.601080      949.499064
# Botswana        Africa      851.241141      918.232535      983.653976
# Burkina Faso    Africa      543.255241      617.183465      722.512021
#
#               gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# country
# Algeria          3246.991771     4182.663766     4910.416756     5745.160213
# Angola           5522.776375     5473.288005     3008.647355     2756.953672
# Benin            1035.831411     1085.796879     1029.161251     1277.897616
# Botswana         1214.709294     2263.611114     3214.857818     4551.142150
# Burkina Faso      794.826560      854.735976      743.387037      807.198586
#
# ...

# %%
df2.head()
# Out:
#              continent  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Algeria         Africa     2449.008185     3013.976023     2550.816880
# Angola          Africa     3520.610273     3827.940465     4269.276742
# Benin           Africa     1062.752200      959.601080      949.499064
# Botswana        Africa      851.241141      918.232535      983.653976
# Burkina Faso    Africa      543.255241      617.183465      722.512021
#
#               gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# country
# Algeria          3246.991771     4182.663766     4910.416756     5745.160213
# Angola           5522.776375     5473.288005     3008.647355     2756.953672
# Benin            1035.831411     1085.796879     1029.161251     1277.897616
# Botswana         1214.709294     2263.611114     3214.857818     4551.142150
# Burkina Faso      794.826560      854.735976      743.387037      807.198586
#
# ...

# %%
len(df.columns)
# Out:
# 38

# %%
df.country.head()
# Out:
# 0         Algeria
# 1          Angola
# 2           Benin
# 3        Botswana
# 4    Burkina Faso
# Name: country, dtype: object

# %%
dfTest = df.iloc[:,list(range(1,14))]
# removes continent

# %%
dfTest.head()
# Out:
#         country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 0       Algeria     2449.008185     3013.976023     2550.816880
# 1        Angola     3520.610273     3827.940465     4269.276742
# 2         Benin     1062.752200      959.601080      949.499064
# 3      Botswana      851.241141      918.232535      983.653976
# 4  Burkina Faso      543.255241      617.183465      722.512021
#
#    gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# 0     3246.991771     4182.663766     4910.416756     5745.160213
# 1     5522.776375     5473.288005     3008.647355     2756.953672
# 2     1035.831411     1085.796879     1029.161251     1277.897616
# 3     1214.709294     2263.611114     3214.857818     4551.142150
# 4      794.826560      854.735976      743.387037      807.198586
#
#    gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  \
# 0     5681.358539     5023.216647     4797.295051     5288.040382
# ...

# %%
dfTest.columns = dfTest.columns.str.replace('gdpPercap_', '')
dfTest
# Out:
#                       country          1952          1957          1962  \
# 0                     Algeria   2449.008185   3013.976023   2550.816880
# 1                      Angola   3520.610273   3827.940465   4269.276742
# 2                       Benin   1062.752200    959.601080    949.499064
# 3                    Botswana    851.241141    918.232535    983.653976
# 4                Burkina Faso    543.255241    617.183465    722.512021
# 5                     Burundi    339.296459    379.564628    355.203227
# 6                    Cameroon   1172.667655   1313.048099   1399.607441
# 7    Central African Republic   1071.310713   1190.844328   1193.068753
# 8                        Chad   1178.665927   1308.495577   1389.817618
# 9                     Comoros   1102.990936   1211.148548   1406.648278
# 10            Congo Dem. Rep.    780.542326    905.860230    896.314634
# 11                 Congo Rep.   2125.621418   2315.056572   2464.783157
# ...

# %%
df_Algeria = dfTest[:1].set_index('country').T.pct_change()

# %%
df_Algeria.head()
# Out:
# country   Algeria
# 1952          NaN
# 1957     0.230693
# 1962    -0.153670
# 1967     0.272922
# 1972     0.288166

# %%
dfTest[:1]
# Out:
#    country         1952         1957        1962         1967         1972  \
# 0  Algeria  2449.008185  3013.976023  2550.81688  3246.991771  4182.663766
#
#           1977         1982         1987         1992         1997  \
# 0  4910.416756  5745.160213  5681.358539  5023.216647  4797.295051
#
#           2002         2007
# 0  5288.040382  6223.367465

# %%
dfTest[:1].T
# Out:
#                0
# country  Algeria
# 1952     2449.01
# 1957     3013.98
# 1962     2550.82
# 1967     3246.99
# 1972     4182.66
# 1977     4910.42
# 1982     5745.16
# 1987     5681.36
# 1992     5023.22
# 1997      4797.3
# 2002     5288.04
# 2007     6223.37

# %%
dfTest[:1].T
# Out:
#                0
# country  Algeria
# 1952     2449.01
# 1957     3013.98
# 1962     2550.82
# 1967     3246.99
# 1972     4182.66
# 1977     4910.42
# 1982     5745.16
# 1987     5681.36
# 1992     5023.22
# 1997      4797.3
# 2002     5288.04
# 2007     6223.37

# %%
dfTest[:1].set_index('country').T
# Out:
# country      Algeria
# 1952     2449.008185
# 1957     3013.976023
# 1962     2550.816880
# 1967     3246.991771
# 1972     4182.663766
# 1977     4910.416756
# 1982     5745.160213
# 1987     5681.358539
# 1992     5023.216647
# 1997     4797.295051
# 2002     5288.040382
# 2007     6223.367465

# %%
dfTest[:1].set_index('country').T.pct_change()
# Out:
# country   Algeria
# 1952          NaN
# 1957     0.230693
# 1962    -0.153670
# 1967     0.272922
# 1972     0.288166
# 1977     0.173993
# 1982     0.169994
# 1987    -0.011105
# 1992    -0.115842
# 1997    -0.044975
# 2002     0.102296
# 2007     0.176876
